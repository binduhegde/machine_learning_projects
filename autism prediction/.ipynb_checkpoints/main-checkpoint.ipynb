# %% [markdown]
# <p style="background: linear-gradient(to right,#c2e59c,#64b3f4);
#           color: transparent;
#           font-family: Gabriola;
#           color: white;
#           font-size: 180%;
#           text-align: center;
#           border-radius: 10px 70px;
#           padding: 15px;">
#    Table of Contents
# </p>

# %% [markdown]
# 1. **About the Dataset**
# 2. **Importing Libraries**
# 3. **Data Cleaning**
#     - Drop Unnecessary columns
#     - Handling Missing Values
#     - Data Formatting
#
#
# 4. **Exploratory Data Analysis**
#     - Distribution of the Features
#     - Correlation Matrix
#
#
# 5. **Data Preprocessing**
#     - One-hot Encoding
#
#
# 6. **Machine Learning Model**
#
# 7. **Deep Learning Model**
#
# 8. **Conclusion**

# %% [markdown]
# <p style="background: linear-gradient(to right,#c2e59c,#64b3f4);
#           color: transparent;
#           font-family: Gabriola;
#           color: white;
#           font-size: 180%;
#           text-align: center;
#           border-radius: 10px 70px;
#           padding: 15px;">
#    1. About the Dataset
# </p>

# %% [markdown]
# This dataset is composed of survey results for more than 700 people who filled an app form. There are labels portraying whether the person received a diagnosis of autism, allowing machine learning models to predict the likelihood of having autism, therefore allowing healthcare professionals prioritize their resources.

# %% [markdown]
# <table><thead><tr><th>Feature</th><th>Description</th></tr></thead><tbody><tr><td>index</td><td>The participant’s ID number</td></tr><tr><td>AX_Score</td><td>Score based on the Autism Spectrum Quotient (AQ) 10 item screening tool <a href="https://docs.autismresearchcentre.com/tests/AQ10.pdf">AQ-10</a></td></tr><tr><td>age</td><td>Age in years</td></tr><tr><td>gender</td><td>Male or Female</td></tr><tr><td>ethnicity</td><td>Ethnicities in text form</td></tr><tr><td>jaundice</td><td>Whether or not the participant was born with jaundice?</td></tr><tr><td>autism</td><td>Whether or not anyone in tbe immediate family has been diagnosed with autism?</td></tr><tr><td>country_of_res</td><td>Countries in text format</td></tr><tr><td>used_app_before</td><td>Whether the participant has used a screening app</td></tr><tr><td>result</td><td>Score from the AQ-10 screening tool</td></tr><tr><td>age_desc</td><td>Age as categorical</td></tr><tr><td>relation</td><td>Relation of person who completed the test</td></tr><tr><td>Class/ASD</td><td>Participant classification</td></tr></tbody></table>

# %% [markdown]
# <p style="background: linear-gradient(to right,#c2e59c,#64b3f4);
#           color: transparent;
#           font-family: Gabriola;
#           color: white;
#           font-size: 180%;
#           text-align: center;
#           border-radius: 10px 70px;
#           padding: 15px;">
#    2. Importing Libraries
# </p>

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import math
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('autism_screening.csv')
df.head()
# Out:
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         1         1         0         0         1
# 1         1         1         0         1         0         0         0
# 2         1         1         0         1         1         0         1
# 3         1         1         0         1         0         0         1
# 4         1         0         0         0         0         0         0
#
#    A8_Score  A9_Score  A10_Score   age gender       ethnicity jundice austim  \
# 0         1         0          0  26.0      f  White-European      no     no
# 1         1         0          1  24.0      m          Latino      no    yes
# 2         1         1          1  27.0      m          Latino     yes    yes
# 3         1         0          1  35.0      f  White-European      no    yes
# 4         1         0          0  40.0      f               ?      no     no
#
#    contry_of_res used_app_before  result     age_desc relation Class/ASD
# 0  United States              no     6.0  18 and more     Self        NO
# 1         Brazil              no     5.0  18 and more     Self        NO
# 2          Spain              no     8.0  18 and more   Parent       YES
# 3  United States              no     6.0  18 and more     Self        NO
# 4          Egypt              no     2.0  18 and more        ?        NO

# %% [markdown]
# <p style="background: linear-gradient(to right,#c2e59c,#64b3f4);
#           color: transparent;
#           font-family: Gabriola;
#           color: white;
#           font-size: 180%;
#           text-align: center;
#           border-radius: 10px 70px;
#           padding: 15px;">
#    3. Data Cleaning
# </p>

# %%
df['A10_Score'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# So all AX_Score are binary

# %% [markdown]
# <p style="background: linear-gradient(to right,#FFAFBD,#C9FFBF);
#           color: transparent;
#           font-family: Gabriola;
#           color: black;
#           font-size: 120%;
#           text-align: center;
#           border-radius: 10px 70px;
#           padding: 10px;">
#    3a. Drop unnecessary Columns
# </p>

# %% [markdown]
# Since age_desc has only one unique value, it's useless. So drop it
#
# I don't think the column 'used_app_before' and 'relation' matters in diagnosis of ASD. do drop it

# %%
df.drop(['age_desc', 'used_app_before', 'relation'], axis=1, inplace=True)

# %% [markdown]
# Renaming 'contry_of_res' to 'country'

# %%
df.rename(columns = {'contry_of_res': 'country', 'jundice':'jaundice', 'austim':'autism'}, inplace=True)

# %%
cat_cols = ['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 
            'A6_Score','A7_Score', 'A8_Score', 'A9_Score', 'A10_Score', 
            'gender', 'ethnicity', 'jaundice', 'autism', 'country']

con_cols = ['age', 'result']

target_col = 'Class/ASD,'

# %% [markdown]
# <p style="background: linear-gradient(to right,#FFAFBD,#C9FFBF);
#           color: transparent;
#           font-family: Gabriola;
#           color: black;
#           font-size: 120%;
#           text-align: center;
#           border-radius: 10px 70px;
#           padding: 10px;">
#    3b. Handling Missing Values
# </p>

# %%
df.isnull().sum()
# Out:
# A1_Score     0
# A2_Score     0
# A3_Score     0
# A4_Score     0
# A5_Score     0
# A6_Score     0
# A7_Score     0
# A8_Score     0
# A9_Score     0
# A10_Score    0
# age          2
# gender       0
# ethnicity    0
# jaundice     0
# autism       0
# country      0
# result       0
# Class/ASD    0
# dtype: int64

# %% [markdown]
# There doesn't seem to be any missing values except for 2 values in age. But the missing values can also be in other forms
#
# like a question mark in the place of the value
#
# or a value like 0 for features like age or even 200. It's just not possible

# %%
# Printing the unique values in every categorical column
for col in cat_cols:
    print(col)
    print(list(df[col].unique()))
    print('-------------')
# Out:
# A1_Score
# [1, 0]
# -------------
# A2_Score
# [1, 0]
# -------------
# A3_Score
# [1, 0]
# -------------
# A4_Score
# [1, 0]
# -------------
# A5_Score
# [0, 1]
# -------------
# A6_Score
# [0, 1]
# -------------
# A7_Score
# [1, 0]
# -------------
# A8_Score
# [1, 0]
# -------------
# A9_Score
# [0, 1]
# -------------
# A10_Score
# [0, 1]
# -------------
# gender
# ['f', 'm']
# -------------
# ethnicity
# ['White-European', 'Latino', '?', 'Others', 'Black', 'Asian', 'Middle Eastern ', 'Pasifika', 'South Asian', 'Hispanic', 'Turkish', 'others']
# -------------
# jaundice
# ['no', 'yes']
# -------------
# autism
# ['no', 'yes']
# -------------
# country
# ['United States', 'Brazil', 'Spain', 'Egypt', 'New Zealand', 'Bahamas', 'Burundi', 'Austria', 'Argentina', 'Jordan', 'Ireland', 'United Arab Emirates', 'Afghanistan', 'Lebanon', 'United Kingdom', 'South Africa', 'Italy', 'Pakistan', 'Bangladesh', 'Chile', 'France', 'China', 'Australia', 'Canada', 'Saudi Arabia', 'Netherlands', 'Romania', 'Sweden', 'Tonga', 'Oman', 'India', 'Philippines', 'Sri Lanka', 'Sierra Leone', 'Ethiopia', 'Viet Nam', 'Iran', 'Costa Rica', 'Germany', 'Mexico', 'Russia', 'Armenia', 'Iceland', 'Nicaragua', 'Hong Kong', 'Japan', 'Ukraine', 'Kazakhstan', 'AmericanSamoa', 'Uruguay', 'Serbia', 'Portugal', 'Malaysia', 'Ecuador', 'Niger', 'Belgium', 'Bolivia', 'Aruba', 'Finland', 'Turkey', 'Nepal', 'Indonesia', 'Angola', 'Azerbaijan', 'Iraq', 'Czech Republic', 'Cyprus']
# -------------

# %% [markdown]
# There are a lot of question marks in these columns:
# - ethnicity

# %% [markdown]
# Can we afford to drop the rows with missing values?

# %% [markdown]
# <p style="background: linear-gradient(to right,#ED9455,white);
#           color: transparent;
#           font-family: Gabriola;
#           color: white;
#           font-size: 80%;
#           text-align: left;
#           padding: 5px;">
#    Handling missing values in the 'ethnicity' column
# </p>

# %%
df.shape
# Out:
# (704, 18)

# %%
sum(df['ethnicity'] == '?')
# Out:
# 95

# %% [markdown]
# Noo. Our dataset only has 700 items, we can't just drop 100 items. We can find which country they are from and assign the race

# %%
df[df['ethnicity'] == '?']['country'].value_counts()
# Out:
# Jordan                  42
# United Arab Emirates    15
# Russia                   5
# New Zealand              5
# Iran                     5
# Afghanistan              3
# Kazakhstan               3
# Argentina                2
# Saudi Arabia             2
# Egypt                    1
# Brazil                   1
# Pakistan                 1
# Azerbaijan               1
# United States            1
# United Kingdom           1
# Hong Kong                1
# Ukraine                  1
# Japan                    1
# Bahamas                  1
# Lebanon                  1
# Austria                  1
# Iraq                     1
# Name: country, dtype: int64

# %% [markdown]
# Most of the missing values belong to jordan and UAE both of which majorly consist of arab people. So let's tream them as arabians

# %% [markdown]
# Let's just group some ethnicities together to reduce the number of unique values
# - White
# - Hispanic (latino included)
# - Middle Eastern (arab included)
# - Black
# - Asian (south asian included)
# - Others (consists of turkish as pasifika groups)

# %%
# grouping ethnicity and decreasing the number of unique ethnicities
ethnicity = {'White-European': 'White', 
             'Latino': 'Hispanic',
             '?': 'Middle Eastern',
             'Pasifika': 'Others',
             'South Asian': 'Asian',
             'Turkish': 'Others', 
             'others': 'Others'}

def assign_ethnicity(string):
    try:
        ethnicity[string]
    except:
        return string


df['ethnicity'] = df['ethnicity'].apply(assign_ethnicity)

# %%
df['ethnicity'].value_counts()
# Out:
# Asian              123
# Middle Eastern      92
# Black               43
# Others              30
# Hispanic            13
# Name: ethnicity, dtype: int64

# %% [markdown]
# <p style="background: linear-gradient(to right,#ED9455,white);
#           color: transparent;
#           font-family: Gabriola;
#           color: white;
#           font-size: 80%;
#           text-align: left;
#           padding: 5px;">
#    Handling missing values in the 'age' column
# </p>

# %%
df['age'].describe()
# Out:
# count    702.000000
# mean      29.698006
# std       16.507465
# min       17.000000
# 25%       21.000000
# 50%       27.000000
# 75%       35.000000
# max      383.000000
# Name: age, dtype: float64

# %% [markdown]
# There can't be someone aged 383 years. So it's a missing value.
# Are there other people whose age is more than, say, 100?

# %%
sum(df['age'] > 100)
# Out:
# 1

# %% [markdown]
# Filling Missing values with the mean

# %%
df['age'].fillna(30, inplace=True)

# %%
df['age'].isnull().sum()
# Out:
# 0

# %%
df['age'].replace({383.0: 30}, inplace=True)

# %%
df['age'].max()
# Out:
# 64.0

# %% [markdown]
# <p style="background: linear-gradient(to right,#FFAFBD,#C9FFBF);
#           color: transparent;
#           font-family: Gabriola;
#           color: black;
#           font-size: 100%;
#           text-align: center;
#           border-radius: 10px 70px;
#           padding: 10px;">
#    3c. Grouping the 'country' column based on the continent
# </p>

# %%
df['country'].nunique()
# Out:
# 67

# %% [markdown]
# There are 67 countries here. one-hot encoding it would increase the model's complexity by a lot. So we're grouping them based on the continent

# %%
def get_continent(input_string):
    continents = {
        'North America': ['United States', 'Canada', 'Bahamas', 'Mexico', 'AmericanSamoa'],
        'South America': ['Brazil', 'Argentina', 'Chile', 'Ecuador', 'Uruguay', 'Bolivia'],
        'Europe': ['Spain', 'Austria', 'Ireland', 'United Kingdom', 'Italy', 'France', 'Netherlands',
                   'Romania', 'Sweden', 'Germany', 'Russia', 'Iceland', 'Belgium', 'Portugal',
                   'Finland', 'Turkey', 'Serbia', 'Czech Republic'],
        'Africa': ['Egypt', 'Burundi', 'South Africa', 'Sierra Leone', 'Ethiopia', 'Niger', 'Angola'],
        'Asia': ['Jordan', 'United Arab Emirates', 'Afghanistan', 'Lebanon', 'Pakistan', 'Bangladesh',
                 'China', 'Saudi Arabia', 'India', 'Philippines', 'Sri Lanka', 'Viet Nam', 'Iran',
                 'Hong Kong', 'Japan', 'Ukraine', 'Kazakhstan', 'Malaysia', 'Cyprus', 'Indonesia',
                 'Azerbaijan', 'Iraq', 'Armenia', 'Nepal'],
        'Oceania': ['New Zealand', 'Australia', 'Tonga']
    }
    
    for continent, countries in continents.items():
        if input_string in countries:
            return continent
    return None
        

df['country'] = df['country'].apply(get_continent)

# %%
df['country'].value_counts()
# Out:
# Asia             284
# Europe           141
# North America    140
# Oceania          109
# South America     15
# Africa            11
# Name: country, dtype: int64

# %%
df['country'].isnull().sum()
# Out:
# 4

# %%
df['country'].fillna('Asia', inplace=True)

# %%
df['country'].isnull().sum()
# Out:
# 0

# %%
df.rename(columns={'country':'continent'}, inplace=True)

# %%
df.columns
# Out:
# Index(['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 'A6_Score',
#        'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score', 'age', 'gender',
#        'ethnicity', 'jaundice', 'autism', 'continent', 'result', 'Class/ASD'],
#       dtype='object')

# %%
cat_cols.remove('country')
cat_cols.append('continent')

# %% [markdown]
# <p style="background: linear-gradient(to right,#FFAFBD,#C9FFBF);
#           color: transparent;
#           font-family: Gabriola;
#           color: black;
#           font-size: 120%;
#           text-align: center;
#           border-radius: 10px 70px;
#           padding: 10px;">
#    3c. Data Formatting
# </p>

# %%
df.dtypes
# Out:
# A1_Score       int64
# A2_Score       int64
# A3_Score       int64
# A4_Score       int64
# A5_Score       int64
# A6_Score       int64
# A7_Score       int64
# A8_Score       int64
# A9_Score       int64
# A10_Score      int64
# age          float64
# gender        object
# ethnicity     object
# jaundice      object
# autism        object
# continent     object
# result       float64
# Class/ASD     object
# dtype: object

# %%
df['Class/ASD'].replace({'YES':1, 'NO':0}, inplace=True)

# %%
df['jaundice'].replace({'yes':1, 'no':0}, inplace=True)
df['autism'].replace({'yes':1, 'no':0}, inplace=True)

# %%
df['gender'].replace({'f':1, 'm':0}, inplace=True)

# %%
df.dtypes
# Out:
# A1_Score       int64
# A2_Score       int64
# A3_Score       int64
# A4_Score       int64
# A5_Score       int64
# A6_Score       int64
# A7_Score       int64
# A8_Score       int64
# A9_Score       int64
# A10_Score      int64
# age          float64
# gender         int64
# ethnicity     object
# jaundice       int64
# autism         int64
# continent     object
# result       float64
# Class/ASD      int64
# dtype: object

# %% [markdown]
# <p style="background: linear-gradient(to right,#c2e59c,#64b3f4);
#           color: transparent;
#           font-family: Gabriola;
#           color: white;
#           font-size: 180%;
#           text-align: center;
#           border-radius: 10px 70px;
#           padding: 15px;">
#    4. Exploratory Data Analysis
# </p>

# %% [markdown]
# <p style="background: linear-gradient(to right,#FFAFBD,#C9FFBF);
#           color: transparent;
#           font-family: Gabriola;
#           color: black;
#           font-size: 120%;
#           text-align: center;
#           border-radius: 10px 70px;
#           padding: 10px;">
#    4a. Distribution of the Features
# </p>

# %% [markdown]
# <p style="background: linear-gradient(to right,#c2e59c,white);
#           color: transparent;
#           font-family: Gabriola;
#           color: black;
#           font-size: 80%;
#           text-align: left;
#           border-radius: 10px 70px;
#           padding: 5px;
#           padding-left: 30px;">
#    Categorical Features
# </p>

# %%
columns = 2
rows = len(cat_cols)

plt.figure(figsize=(columns*5, rows*5))

for i, col in enumerate(cat_cols):
    data = df[col].value_counts()
    plt.subplot(rows, columns, (i*2)+1)
    sns.barplot(x=data.index, y=data, palette='Set3')
    
    plt.subplot(rows, columns, (i*2)+2)
    sns.barplot(x=df[col], y=df['Class/ASD'])
    
    
plt.show()

# %% [markdown]
# <p style="background: linear-gradient(to right,#c2e59c,white);
#           color: transparent;
#           font-family: Gabriola;
#           color: black;
#           font-size: 80%;
#           text-align: left;
#           border-radius: 10px 70px;
#           padding: 5px;
#           padding-left: 30px;">
#    Continuous Features
# </p>

# %%
columns = 2
rows = len(con_cols)

plt.figure(figsize=(columns*5, rows*5))

for i, col in enumerate(con_cols):
    plt.subplot(rows, columns, (i*2)+1)
    sns.distplot(x=df[col])
    
    plt.subplot(rows, columns, (i*2)+2)
    sns.barplot(y=df[col], x=df['Class/ASD'], palette='Set3')
    break
    
    
plt.show()

# %% [markdown]
# <p style="background: linear-gradient(to right,#c2e59c,white);
#           color: transparent;
#           font-family: Gabriola;
#           color: black;
#           font-size: 80%;
#           text-align: left;
#           border-radius: 10px 70px;
#           padding: 5px;
#           padding-left: 30px;">
#    Observations
# </p>

# %% [markdown]
# - People who have answered 'yes' for the questions asked tend to have ASD
# - People whose have an immediate family member with ASD have better chance of having ASD themselves. So ASD can be hereditary
# - neonatal jaundice may be associated with autism spectrum disorder (ASD) and may increase the risk of ASD. This is interesting
# - The ASD rate in asia is much less compared to that of North America and other continents
# - Age doesn't seem to be affecting the result

# %% [markdown]
# <p style="background: linear-gradient(to right,#FFAFBD,#C9FFBF);
#           color: transparent;
#           font-family: Gabriola;
#           color: black;
#           font-size: 120%;
#           text-align: center;
#           border-radius: 10px 70px;
#           padding: 10px;">
#    4b. Correlation Matrix
# </p>

# %%
df_corr = df.corr()
mask = np.triu(np.ones_like(df_corr))
corr = df_corr.transpose()
cmap = sns.diverging_palette(70,20,s=50, l=40, n=6,as_cmap=True)

plt.figure(figsize=(15, 12))
sns.heatmap(corr, mask=mask, cmap=cmap, annot=True)
plt.show()

# %% [markdown]
# There is high correlation between the result and having ASD which is obvious because that result has to play an important role in the diagnosis right

# %% [markdown]
# <p style="background: linear-gradient(to right,#c2e59c,#64b3f4);
#           color: transparent;
#           font-family: Gabriola;
#           color: white;
#           font-size: 180%;
#           text-align: center;
#           border-radius: 10px 70px;
#           padding: 15px;">
#    5. Data Preprocessing
# </p>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %% [markdown]
# <p style="background: linear-gradient(to right,#FFAFBD,#C9FFBF);
#           color: transparent;
#           font-family: Gabriola;
#           color: black;
#           font-size: 120%;
#           text-align: center;
#           border-radius: 10px 70px;
#           padding: 10px;">
#    5a. One-hot Encoding
# </p>

# %%
df = pd.get_dummies(df, columns=['continent', 'ethnicity'])

# %%
df.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('float64'), dtype('uint8')], dtype=object)

# %%
x = df.drop(['Class/ASD'], axis=1)
y = df['Class/ASD']

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3, random_state=2)

# %% [markdown]
# <p style="background: linear-gradient(to right,#c2e59c,#64b3f4);
#           color: transparent;
#           font-family: Gabriola;
#           color: white;
#           font-size: 180%;
#           text-align: center;
#           border-radius: 10px 70px;
#           padding: 15px;">
#    6. Machine Learning Model
# </p>

# %%
models = {
    'Logistic Regression': LogisticRegression(),
    'Random Forest': RandomForestClassifier(),
    'Support Vector Machine': SVC()
}

# %%
result = {}

for name, model in models.items():
    model.fit(xtrain, ytrain)
    pred = model.predict(xtest)
    score = accuracy_score(pred, ytest)
    result[name] = score
    
result
# Out:
# {'Logistic Regression': 1.0,
#  'Random Forest': 1.0,
#  'Support Vector Machine': 0.9716981132075472}

# %% [markdown]
# <p style="background: linear-gradient(to right,#c2e59c,#64b3f4);
#           color: transparent;
#           font-family: Gabriola;
#           color: white;
#           font-size: 180%;
#           text-align: center;
#           border-radius: 10px 70px;
#           padding: 15px;">
#    7. Deep Learning Model
# </p>

# %%
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras import callbacks

# %%
early_stopping = callbacks.EarlyStopping(
                min_delta=0.001, 
                patience = 10,
                restore_best_weights=True
                )

# %%
len(x.columns)
# Out:
# 26

# %% [markdown]
# <p style="background: linear-gradient(to right,#ED9455,white);
#           color: transparent;
#           font-family: Gabriola;
#           color: white;
#           font-size: 80%;
#           text-align: left;
#           padding: 5px;
#           padding-left: 10px;">
#    Initializing the Neural Network
# </p>

# %% [markdown]
# We are going to start with the Dense units as:
# - 30: About the size of the input dimension
# - 50: About twice the size of the first layer
# - 50: About twice the size of the first layer
# - 1 : The size of the input. It's a single number

# %%
# Initializing the NN
model = Sequential()

model.add(Dense(units = 30, activation='relu', input_dim=26))

model.add(Dense(units = 50, activation='relu'))

model.add(Dropout(0.25))

model.add(Dense(units = 50, activation= 'relu'))

model.add(Dropout(0.5))

model.add(Dense(units=1, activation='sigmoid'))
# Out:
# 2024-04-21 10:18:04.741682: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# <p style="background: linear-gradient(to right,#ED9455,white);
#           color: transparent;
#           font-family: Gabriola;
#           color: white;
#           font-size: 80%;
#           text-align: left;
#           padding: 5px;
#           padding-left: 10px;">
#    Compiling the Model
# </p>

# %%
model.compile(optimizer='adam', 
             loss = 'binary_crossentropy',
              
             metrics = ['accuracy'])

# %% [markdown]
# <p style="background: linear-gradient(to right,#ED9455,white);
#           color: transparent;
#           font-family: Gabriola;
#           color: white;
#           font-size: 80%;
#           text-align: left;
#           padding: 5px;
#           padding-left: 10px;">
#    Fitting the Model
# </p>

# %%
history = model.fit(xtrain, ytrain,
                   batch_size = 10,
                   callbacks = [early_stopping],
                   epochs = 100, 
                   validation_split = 0.2)
# Out:
# 2024-04-21 10:18:04.942071: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 40/40 [==============================] - 1s 9ms/step - loss: 0.9023 - accuracy: 0.6463 - val_loss: 0.4482 - val_accuracy: 0.8081
# Epoch 2/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5077 - accuracy: 0.7786 - val_loss: 0.3426 - val_accuracy: 0.8687
# Epoch 3/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4637 - accuracy: 0.7837 - val_loss: 0.2816 - val_accuracy: 0.9091
# Epoch 4/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4041 - accuracy: 0.8372 - val_loss: 0.2814 - val_accuracy: 0.8990
# Epoch 5/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.3700 - accuracy: 0.8346 - val_loss: 0.2243 - val_accuracy: 0.9192
# Epoch 6/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.3219 - accuracy: 0.8702 - val_loss: 0.2114 - val_accuracy: 0.9192
# Epoch 7/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.3234 - accuracy: 0.8499 - val_loss: 0.2261 - val_accuracy: 0.8990
# Epoch 8/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2862 - accuracy: 0.8702 - val_loss: 0.2892 - val_accuracy: 0.8687
# Epoch 9/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2863 - accuracy: 0.8855 - val_loss: 0.2032 - val_accuracy: 0.9293
# Epoch 10/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2740 - accuracy: 0.8779 - val_loss: 0.1920 - val_accuracy: 0.9394
# Epoch 11/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2410 - accuracy: 0.8931 - val_loss: 0.1854 - val_accuracy: 0.9394
# Epoch 12/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2175 - accuracy: 0.9008 - val_loss: 0.1734 - val_accuracy: 0.9495
# Epoch 13/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2024 - accuracy: 0.9186 - val_loss: 0.1713 - val_accuracy: 0.9293
# Epoch 14/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2343 - accuracy: 0.8931 - val_loss: 0.1875 - val_accuracy: 0.8990
# Epoch 15/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2294 - accuracy: 0.8906 - val_loss: 0.1756 - val_accuracy: 0.9293
# Epoch 16/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1920 - accuracy: 0.9211 - val_loss: 0.1580 - val_accuracy: 0.9495
# Epoch 17/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2033 - accuracy: 0.9135 - val_loss: 0.1946 - val_accuracy: 0.9293
# Epoch 18/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1876 - accuracy: 0.9262 - val_loss: 0.1974 - val_accuracy: 0.8889
# Epoch 19/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1875 - accuracy: 0.9288 - val_loss: 0.1755 - val_accuracy: 0.9394
# Epoch 20/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1769 - accuracy: 0.9135 - val_loss: 0.1751 - val_accuracy: 0.9293
# Epoch 21/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1589 - accuracy: 0.9338 - val_loss: 0.1589 - val_accuracy: 0.9192
# Epoch 22/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1730 - accuracy: 0.9415 - val_loss: 0.1863 - val_accuracy: 0.9091
# Epoch 23/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1472 - accuracy: 0.9440 - val_loss: 0.1622 - val_accuracy: 0.9293
# Epoch 24/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1488 - accuracy: 0.9237 - val_loss: 0.1750 - val_accuracy: 0.9293
# Epoch 25/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1663 - accuracy: 0.9237 - val_loss: 0.2449 - val_accuracy: 0.8889
# Epoch 26/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1534 - accuracy: 0.9237 - val_loss: 0.2943 - val_accuracy: 0.8586

# %% [markdown]
# <p style="background: linear-gradient(to right,#ED9455,white);
#           color: transparent;
#           font-family: Gabriola;
#           color: white;
#           font-size: 80%;
#           text-align: left;
#           padding: 5px;
#           padding-left: 10px;">
#    Model Evaluation
# </p>

# %%
max(history.history['val_accuracy'])
# Out:
# 0.9494949579238892

# %% [markdown]
# <p style="background: linear-gradient(to right,#ED9455,white);
#           color: transparent;
#           font-family: Gabriola;
#           color: white;
#           font-size: 80%;
#           text-align: left;
#           padding: 7px;
#           padding-left: 10px;">
#    Improving model's accuracy
# </p>

# %% [markdown]
# This time, We have only one hidden layer

# %%
# Initializing the NN
model2 = Sequential()

model2.add(Dense(units = 30, activation='relu', input_dim=26))

model2.add(Dense(units = 50, activation='relu'))

model2.add(Dense(units=1, activation='sigmoid'))


model2.compile(optimizer='adam', 
             loss = 'binary_crossentropy',
             metrics = ['accuracy'])

history2 = model2.fit(xtrain, ytrain,
                   batch_size = 10,
                   callbacks = [early_stopping],
                   epochs = 100, 
                   validation_split = 0.2)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 1s 6ms/step - loss: 0.6599 - accuracy: 0.7099 - val_loss: 0.4963 - val_accuracy: 0.7879
# Epoch 2/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.4563 - accuracy: 0.8041 - val_loss: 0.3875 - val_accuracy: 0.8384
# Epoch 3/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.3657 - accuracy: 0.8601 - val_loss: 0.3174 - val_accuracy: 0.8788
# Epoch 4/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.3120 - accuracy: 0.8804 - val_loss: 0.2790 - val_accuracy: 0.9091
# Epoch 5/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2859 - accuracy: 0.8753 - val_loss: 0.2469 - val_accuracy: 0.9293
# Epoch 6/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2521 - accuracy: 0.8957 - val_loss: 0.2270 - val_accuracy: 0.9192
# Epoch 7/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2328 - accuracy: 0.9059 - val_loss: 0.2149 - val_accuracy: 0.8990
# Epoch 8/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2121 - accuracy: 0.9160 - val_loss: 0.2046 - val_accuracy: 0.9394
# Epoch 9/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1946 - accuracy: 0.9211 - val_loss: 0.2356 - val_accuracy: 0.8889
# Epoch 10/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1863 - accuracy: 0.9211 - val_loss: 0.1851 - val_accuracy: 0.9394
# Epoch 11/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1981 - accuracy: 0.9135 - val_loss: 0.3039 - val_accuracy: 0.8485
# Epoch 12/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1638 - accuracy: 0.9415 - val_loss: 0.2100 - val_accuracy: 0.8990
# Epoch 13/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1587 - accuracy: 0.9364 - val_loss: 0.1756 - val_accuracy: 0.9394
# Epoch 14/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1632 - accuracy: 0.9262 - val_loss: 0.1702 - val_accuracy: 0.9394
# Epoch 15/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1549 - accuracy: 0.9466 - val_loss: 0.2141 - val_accuracy: 0.8990
# Epoch 16/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1423 - accuracy: 0.9364 - val_loss: 0.2062 - val_accuracy: 0.9192
# Epoch 17/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1381 - accuracy: 0.9491 - val_loss: 0.1713 - val_accuracy: 0.9192
# Epoch 18/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1516 - accuracy: 0.9415 - val_loss: 0.1982 - val_accuracy: 0.9091
# Epoch 19/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1211 - accuracy: 0.9517 - val_loss: 0.1603 - val_accuracy: 0.9495
# Epoch 20/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1298 - accuracy: 0.9542 - val_loss: 0.1624 - val_accuracy: 0.9293
# Epoch 21/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1189 - accuracy: 0.9593 - val_loss: 0.1906 - val_accuracy: 0.9192
# Epoch 22/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1162 - accuracy: 0.9644 - val_loss: 0.1577 - val_accuracy: 0.9394
# Epoch 23/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1257 - accuracy: 0.9389 - val_loss: 0.1680 - val_accuracy: 0.9495
# Epoch 24/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1042 - accuracy: 0.9644 - val_loss: 0.1647 - val_accuracy: 0.9293
# Epoch 25/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0975 - accuracy: 0.9669 - val_loss: 0.1626 - val_accuracy: 0.9495
# Epoch 26/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0942 - accuracy: 0.9720 - val_loss: 0.1883 - val_accuracy: 0.9091
# Epoch 27/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0943 - accuracy: 0.9695 - val_loss: 0.1536 - val_accuracy: 0.9495
# Epoch 28/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1002 - accuracy: 0.9644 - val_loss: 0.1534 - val_accuracy: 0.9596
# Epoch 29/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1140 - accuracy: 0.9466 - val_loss: 0.2067 - val_accuracy: 0.9091
# Epoch 30/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0845 - accuracy: 0.9695 - val_loss: 0.1825 - val_accuracy: 0.9293
# Epoch 31/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0849 - accuracy: 0.9796 - val_loss: 0.1461 - val_accuracy: 0.9495
# Epoch 32/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0738 - accuracy: 0.9720 - val_loss: 0.1958 - val_accuracy: 0.9192
# Epoch 33/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0866 - accuracy: 0.9771 - val_loss: 0.1494 - val_accuracy: 0.9596
# Epoch 34/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0842 - accuracy: 0.9720 - val_loss: 0.1721 - val_accuracy: 0.9293
# Epoch 35/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0787 - accuracy: 0.9669 - val_loss: 0.1465 - val_accuracy: 0.9495
# Epoch 36/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0799 - accuracy: 0.9695 - val_loss: 0.1626 - val_accuracy: 0.9394
# Epoch 37/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0588 - accuracy: 0.9873 - val_loss: 0.1460 - val_accuracy: 0.9596
# Epoch 38/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0626 - accuracy: 0.9771 - val_loss: 0.1614 - val_accuracy: 0.9394
# Epoch 39/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0627 - accuracy: 0.9796 - val_loss: 0.1585 - val_accuracy: 0.9394
# Epoch 40/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0674 - accuracy: 0.9720 - val_loss: 0.1508 - val_accuracy: 0.9596
# Epoch 41/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0539 - accuracy: 0.9796 - val_loss: 0.1461 - val_accuracy: 0.9596

# %%
max(history2.history['val_accuracy'])
# Out:
# 0.9595959782600403

# %% [markdown]
# This is definitely better than the last model. Let's change the activation function of the hidden layer from 'relu' to 'linear'

# %%
# Initializing the NN
model3 = Sequential()

model3.add(Dense(units = 30, activation='relu', input_dim=26))

model3.add(Dense(units = 50, activation='linear'))

model3.add(Dense(units=1, activation='sigmoid'))


model3.compile(optimizer='adam', 
             loss = 'binary_crossentropy',
             metrics = ['accuracy'])

history3 = model3.fit(xtrain, ytrain,
                   batch_size = 10,
                   callbacks = [early_stopping],
                   epochs = 100, 
                   validation_split = 0.2)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 1s 6ms/step - loss: 0.6723 - accuracy: 0.6616 - val_loss: 0.5654 - val_accuracy: 0.7172
# Epoch 2/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5140 - accuracy: 0.7888 - val_loss: 0.4496 - val_accuracy: 0.7980
# Epoch 3/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4058 - accuracy: 0.8524 - val_loss: 0.3609 - val_accuracy: 0.8788
# Epoch 4/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.3345 - accuracy: 0.8855 - val_loss: 0.3054 - val_accuracy: 0.8990
# Epoch 5/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.3217 - accuracy: 0.8728 - val_loss: 0.2718 - val_accuracy: 0.9293
# Epoch 6/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2652 - accuracy: 0.8982 - val_loss: 0.2437 - val_accuracy: 0.9091
# Epoch 7/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2447 - accuracy: 0.9084 - val_loss: 0.2270 - val_accuracy: 0.9091
# Epoch 8/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2299 - accuracy: 0.8982 - val_loss: 0.3052 - val_accuracy: 0.8384
# Epoch 9/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2386 - accuracy: 0.9008 - val_loss: 0.2026 - val_accuracy: 0.9495
# Epoch 10/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2064 - accuracy: 0.9160 - val_loss: 0.1981 - val_accuracy: 0.9394
# Epoch 11/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2041 - accuracy: 0.9160 - val_loss: 0.1946 - val_accuracy: 0.9394
# Epoch 12/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2527 - accuracy: 0.8880 - val_loss: 0.2573 - val_accuracy: 0.8586
# Epoch 13/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1785 - accuracy: 0.9288 - val_loss: 0.1866 - val_accuracy: 0.9293
# Epoch 14/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1687 - accuracy: 0.9313 - val_loss: 0.2368 - val_accuracy: 0.8586
# Epoch 15/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1669 - accuracy: 0.9262 - val_loss: 0.1810 - val_accuracy: 0.9495
# Epoch 16/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1601 - accuracy: 0.9288 - val_loss: 0.2597 - val_accuracy: 0.8586
# Epoch 17/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1574 - accuracy: 0.9313 - val_loss: 0.1832 - val_accuracy: 0.9293
# Epoch 18/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1566 - accuracy: 0.9389 - val_loss: 0.1956 - val_accuracy: 0.8889
# Epoch 19/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1589 - accuracy: 0.9313 - val_loss: 0.1696 - val_accuracy: 0.9394
# Epoch 20/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1431 - accuracy: 0.9415 - val_loss: 0.1761 - val_accuracy: 0.9394
# Epoch 21/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1346 - accuracy: 0.9415 - val_loss: 0.1986 - val_accuracy: 0.8788
# Epoch 22/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1369 - accuracy: 0.9517 - val_loss: 0.1973 - val_accuracy: 0.8788
# Epoch 23/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1413 - accuracy: 0.9389 - val_loss: 0.1792 - val_accuracy: 0.9091
# Epoch 24/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1336 - accuracy: 0.9593 - val_loss: 0.1664 - val_accuracy: 0.9293
# Epoch 25/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1424 - accuracy: 0.9415 - val_loss: 0.2481 - val_accuracy: 0.8788
# Epoch 26/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1283 - accuracy: 0.9389 - val_loss: 0.1739 - val_accuracy: 0.9091
# Epoch 27/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1203 - accuracy: 0.9542 - val_loss: 0.1867 - val_accuracy: 0.8990
# Epoch 28/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1182 - accuracy: 0.9567 - val_loss: 0.1650 - val_accuracy: 0.9293
# Epoch 29/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1345 - accuracy: 0.9542 - val_loss: 0.1832 - val_accuracy: 0.9091
# Epoch 30/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1507 - accuracy: 0.9364 - val_loss: 0.1573 - val_accuracy: 0.9394
# Epoch 31/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1244 - accuracy: 0.9567 - val_loss: 0.1580 - val_accuracy: 0.9394
# Epoch 32/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1070 - accuracy: 0.9618 - val_loss: 0.1569 - val_accuracy: 0.9293
# Epoch 33/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.9644 - val_loss: 0.1596 - val_accuracy: 0.9394
# Epoch 34/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1136 - accuracy: 0.9491 - val_loss: 0.1717 - val_accuracy: 0.9293
# Epoch 35/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0992 - accuracy: 0.9669 - val_loss: 0.1604 - val_accuracy: 0.9495
# Epoch 36/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1493 - accuracy: 0.9364 - val_loss: 0.2673 - val_accuracy: 0.8687
# Epoch 37/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0926 - accuracy: 0.9720 - val_loss: 0.1547 - val_accuracy: 0.9394
# Epoch 38/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1025 - accuracy: 0.9618 - val_loss: 0.1587 - val_accuracy: 0.9495
# Epoch 39/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0895 - accuracy: 0.9644 - val_loss: 0.2081 - val_accuracy: 0.9091
# Epoch 40/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0999 - accuracy: 0.9644 - val_loss: 0.1736 - val_accuracy: 0.9293
# Epoch 41/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0971 - accuracy: 0.9593 - val_loss: 0.1982 - val_accuracy: 0.9192
# Epoch 42/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1042 - accuracy: 0.9567 - val_loss: 0.1813 - val_accuracy: 0.9293
# Epoch 43/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0813 - accuracy: 0.9695 - val_loss: 0.1462 - val_accuracy: 0.9495
# Epoch 44/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1019 - accuracy: 0.9593 - val_loss: 0.1497 - val_accuracy: 0.9192
# Epoch 45/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0932 - accuracy: 0.9567 - val_loss: 0.1478 - val_accuracy: 0.9495
# Epoch 46/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0790 - accuracy: 0.9618 - val_loss: 0.1389 - val_accuracy: 0.9495
# Epoch 47/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0800 - accuracy: 0.9720 - val_loss: 0.1692 - val_accuracy: 0.9192
# Epoch 48/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0795 - accuracy: 0.9771 - val_loss: 0.1847 - val_accuracy: 0.9192
# Epoch 49/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0867 - accuracy: 0.9746 - val_loss: 0.1482 - val_accuracy: 0.9394
# Epoch 50/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0856 - accuracy: 0.9695 - val_loss: 0.1345 - val_accuracy: 0.9495
# Epoch 51/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 0.9746 - val_loss: 0.1488 - val_accuracy: 0.9293
# Epoch 52/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0726 - accuracy: 0.9695 - val_loss: 0.1781 - val_accuracy: 0.9192
# Epoch 53/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0641 - accuracy: 0.9796 - val_loss: 0.1427 - val_accuracy: 0.9495
# Epoch 54/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0639 - accuracy: 0.9746 - val_loss: 0.1360 - val_accuracy: 0.9495
# Epoch 55/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0648 - accuracy: 0.9771 - val_loss: 0.1382 - val_accuracy: 0.9495
# Epoch 56/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0814 - accuracy: 0.9669 - val_loss: 0.1405 - val_accuracy: 0.9293
# Epoch 57/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0577 - accuracy: 0.9847 - val_loss: 0.1472 - val_accuracy: 0.9293
# Epoch 58/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0624 - accuracy: 0.9771 - val_loss: 0.1398 - val_accuracy: 0.9394
# Epoch 59/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0538 - accuracy: 0.9796 - val_loss: 0.1290 - val_accuracy: 0.9394
# Epoch 60/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0535 - accuracy: 0.9822 - val_loss: 0.1384 - val_accuracy: 0.9495
# Epoch 61/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0495 - accuracy: 0.9873 - val_loss: 0.1915 - val_accuracy: 0.9293
# Epoch 62/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0629 - accuracy: 0.9822 - val_loss: 0.1448 - val_accuracy: 0.9293
# Epoch 63/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0588 - accuracy: 0.9720 - val_loss: 0.1277 - val_accuracy: 0.9495
# Epoch 64/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1001 - accuracy: 0.9567 - val_loss: 0.1894 - val_accuracy: 0.9394
# Epoch 65/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0615 - accuracy: 0.9796 - val_loss: 0.1785 - val_accuracy: 0.9091
# Epoch 66/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0463 - accuracy: 0.9822 - val_loss: 0.1214 - val_accuracy: 0.9596
# Epoch 67/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0456 - accuracy: 0.9898 - val_loss: 0.1233 - val_accuracy: 0.9596
# Epoch 68/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0406 - accuracy: 0.9898 - val_loss: 0.1159 - val_accuracy: 0.9596
# Epoch 69/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0399 - accuracy: 0.9898 - val_loss: 0.1552 - val_accuracy: 0.9495
# Epoch 70/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0384 - accuracy: 0.9924 - val_loss: 0.1195 - val_accuracy: 0.9495
# Epoch 71/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0503 - accuracy: 0.9873 - val_loss: 0.1956 - val_accuracy: 0.9192
# Epoch 72/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0420 - accuracy: 0.9873 - val_loss: 0.1743 - val_accuracy: 0.9192
# Epoch 73/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0510 - accuracy: 0.9771 - val_loss: 0.1167 - val_accuracy: 0.9495
# Epoch 74/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0368 - accuracy: 0.9949 - val_loss: 0.1186 - val_accuracy: 0.9293
# Epoch 75/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0498 - accuracy: 0.9796 - val_loss: 0.1130 - val_accuracy: 0.9495
# Epoch 76/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0327 - accuracy: 0.9898 - val_loss: 0.2169 - val_accuracy: 0.9192
# Epoch 77/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0321 - accuracy: 0.9924 - val_loss: 0.1180 - val_accuracy: 0.9596
# Epoch 78/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0391 - accuracy: 0.9924 - val_loss: 0.1157 - val_accuracy: 0.9596
# Epoch 79/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0352 - accuracy: 0.9924 - val_loss: 0.1000 - val_accuracy: 0.9596
# Epoch 80/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0356 - accuracy: 0.9873 - val_loss: 0.1146 - val_accuracy: 0.9394
# Epoch 81/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0342 - accuracy: 0.9949 - val_loss: 0.1677 - val_accuracy: 0.9293
# Epoch 82/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0370 - accuracy: 0.9847 - val_loss: 0.1166 - val_accuracy: 0.9596
# Epoch 83/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0404 - accuracy: 0.9847 - val_loss: 0.2128 - val_accuracy: 0.9192
# Epoch 84/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0304 - accuracy: 0.9898 - val_loss: 0.1575 - val_accuracy: 0.9394
# Epoch 85/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0279 - accuracy: 0.9924 - val_loss: 0.1127 - val_accuracy: 0.9495
# Epoch 86/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0282 - accuracy: 0.9949 - val_loss: 0.1129 - val_accuracy: 0.9596
# Epoch 87/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.1096 - val_accuracy: 0.9697
# Epoch 88/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0322 - accuracy: 0.9924 - val_loss: 0.1612 - val_accuracy: 0.9495
# Epoch 89/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0271 - accuracy: 0.9949 - val_loss: 0.1017 - val_accuracy: 0.9495

# %%
max(history3.history['val_accuracy'])
# Out:
# 0.9696969985961914

# %% [markdown]
# <p style="background: linear-gradient(to right,#c2e59c,#64b3f4);
#           color: transparent;
#           font-family: Gabriola;
#           color: white;
#           font-size: 180%;
#           text-align: center;
#           border-radius: 10px 70px;
#           padding: 15px;">
#    8. Conclusion
# </p>

# %% [markdown]
# - **Random Forest** algorithm gave us an awesome accuracy of **100%**
# - Deep learning model with one hidden layer and the dense units as **[30, 50, 1]** and the activation functions as **[relu, linear, sigmoid]** and with **100 epochs** (early stopping applid) gives us an accuracy of **97%**
